# %%
import yfinance as yf

# %%
stock = 'sauce.bk'
data = yf.Ticker(stock)
stock
# Out:
# 'sauce.bk'

# %%
data_historical = data.history(start='2023-01-01',end ='2023-12-31',interval = '1d')
print(data_historical.columns)
data_historical['Close'].plot()
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')
# <Axes: xlabel='Date'>

# %%
stock_list = ['sauce.bk xo.bk']
data = yf.download('sauce.bk xo.bk', start="2024-01-01", end="2024-03-31")
data['Close'].plot()
# Out:
# [*********************100%%**********************]  2 of 2 completed
# <Axes: xlabel='Date'>

# %%
stock_list = ['sauce.bk xo.bk']
data = yf.download('sauce.bk xo.bk', start="2024-03-01", end="2024-03-31",group_by='tickers')
data
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Ticker          XO.BK                                                        \
# Price            Open       High        Low      Close  Adj Close    Volume
# Date
# 2024-03-01  24.200001  24.400000  23.600000  23.600000  23.070002   1679500
# 2024-03-04  23.700001  25.500000  23.700001  25.000000  24.438560   4006200
# 2024-03-05  25.000000  26.000000  22.600000  23.200001  22.678984  15974100
# 2024-03-06  23.200001  24.400000  23.200001  23.600000  23.070002   5506500
# 2024-03-07  23.200001  23.299999  22.799999  22.900000  22.900000   2894300
# 2024-03-08  23.000000  23.299999  22.900000  22.900000  22.900000    995600
# 2024-03-11  23.200001  23.200001  22.700001  22.700001  22.700001   1444500
# 2024-03-12  22.700001  22.700001  22.700001  22.700001  22.700001         0
# 2024-03-13  26.500000  27.250000  26.250000  27.000000  27.000000   8107800
# ...

# %% [markdown]
# #### Yfinance to acquire fundamental data ######

# %%
stock = 'sauce.bk'
data = yf.Ticker(stock)
data.info
# Out:
# {'address1': '208 Moo 6 Taiban Road',
#  'address2': 'Taiban Sub-District Muang District',
#  'city': 'Samutprakarn',
#  'zip': '10280',
#  'country': 'Thailand',
#  'phone': '66 2 703 4444',
#  'fax': '66 2 387 1163',
#  'website': 'https://www.thaitheparos.com',
#  'industry': 'Packaged Foods',
#  'industryKey': 'packaged-foods',
#  'industryDisp': 'Packaged Foods',
#  'sector': 'Consumer Defensive',
#  'sectorKey': 'consumer-defensive',
#  'sectorDisp': 'Consumer Defensive',
# ...

# %%
#### Yfinance to acquire fundamental data and print a particular attribute ######
data.info['currentPrice']
# Out:
# 40.25

# %%
data.quarterly_financials
# Out:
#                                                      2024-03-31   2023-12-31  \
# Tax Effect Of Unusual Items                                 0.0          0.0
# Tax Rate For Calcs                                     0.199911     0.203893
# Normalized EBITDA                                   256010000.0  258231715.0
# Net Income From Continuing Operation Net Minori...  197878000.0  197459415.0
# Reconciled Depreciation                              24739000.0   25190452.0
# Reconciled Cost Of Revenue                          556070000.0  552274000.0
# EBITDA                                              256010000.0  258231715.0
# EBIT                                                231271000.0  233041263.0
# Normalized Income                                   197878000.0  197459415.0
# Net Income From Continuing And Discontinued Ope...  197878000.0  197459415.0
# Total Expenses                                      663934000.0  668905830.0
# ...

# %%
# data_ebit_ttm = data.quarterly_financials['EBIT'].sum(axis=1)
# data_ebit_ttm
test = data.quarterly_financials
list_col = test.columns
test = test.reset_index()
print(list_col)
test['ttm'] = 0
ttm_period = 4
for i in range(4):
    test['ttm'] = test['ttm'] + test[list_col[i]]

test = test.set_index('index')
test
# Out:
# DatetimeIndex(['2024-03-31', '2023-12-31', '2023-09-30', '2023-06-30',
#                '2023-03-31', '2022-12-31'],
#               dtype='datetime64[ns]', freq=None)
#                                                    2024-03-31 00:00:00  \
# index
# Tax Effect Of Unusual Items                                        0.0
# Tax Rate For Calcs                                            0.199911
# Normalized EBITDA                                          256010000.0
# Net Income From Continuing Operation Net Minori...         197878000.0
# Reconciled Depreciation                                     24739000.0
# Reconciled Cost Of Revenue                                 556070000.0
# EBITDA                                                     256010000.0
# EBIT                                                       231271000.0
# Normalized Income                                          197878000.0
# Net Income From Continuing And Discontinued Ope...         197878000.0
# ...

# %%
test.loc[test.index == 'EBIT']
# Out:
#       2024-03-31 00:00:00 2023-12-31 00:00:00 2023-09-30 00:00:00  \
# index
# EBIT          231271000.0         233041263.0         215237000.0
#
#       2023-06-30 00:00:00 2023-03-31 00:00:00 2022-12-31 00:00:00          ttm
# index
# EBIT          226312000.0         200441000.0                 NaN  905861263.0

# %% [markdown]
# ### Acquire fundamental data for stock list #####

# %%
import pandas as pd
tickers_list= ['xo.bk','sauce.bk']
tickers_data = {}

# %%
for ticker in tickers_list:
    ticker_object = yf.Ticker(ticker)

    #convert info() output from dictionary to dataframe
    temp = pd.DataFrame.from_dict(ticker_object.info, orient="index")
    temp.reset_index(inplace=True)
    temp.columns = ["Attribute", "Recent"]
    
    # add (ticker, dataframe) to main dictionary
    tickers_data[ticker] = temp

tickers_data
# Out:
# {'xo.bk':              Attribute                                             Recent
#  0             address1                         130 - 132 Sindhorn Tower 2
#  1             address2  9th floor, Wireless Road Kwang Lumpini Khet Pa...
#  2                 city                                            Bangkok
#  3                  zip                                              10330
#  4              country                                           Thailand
#  ..                 ...                                                ...
#  107       grossMargins                                            0.48222
#  108      ebitdaMargins                                            0.36215
#  109   operatingMargins                                             0.3729
#  110  financialCurrency                                                THB
#  111   trailingPegRatio                                               None
#
#  [112 rows x 2 columns],
# ...

# %%
combined_data = pd.concat(tickers_data)
combined_data = combined_data.reset_index()
combined_data
# Out:
#       level_0  level_1          Attribute  \
# 0       xo.bk        0           address1
# 1       xo.bk        1           address2
# 2       xo.bk        2               city
# 3       xo.bk        3                zip
# 4       xo.bk        4            country
# ..        ...      ...                ...
# 211  sauce.bk       99       grossMargins
# 212  sauce.bk      100      ebitdaMargins
# 213  sauce.bk      101   operatingMargins
# 214  sauce.bk      102  financialCurrency
# 215  sauce.bk      103   trailingPegRatio
#
#                                                 Recent
# 0                           130 - 132 Sindhorn Tower 2
# 1    9th floor, Wireless Road Kwang Lumpini Khet Pa...
# 2                                              Bangkok
# 3                                                10330
# 4                                             Thailand
# ..                                                 ...
# 211                                            0.41687
# ...

# %%
del combined_data["level_1"] # clean up unnecessary column
combined_data.columns = ["Ticker", "Attribute", "Recent"] # update column names

combined_data
# Out:
#        Ticker          Attribute  \
# 0       xo.bk           address1
# 1       xo.bk           address2
# 2       xo.bk               city
# 3       xo.bk                zip
# 4       xo.bk            country
# ..        ...                ...
# 211  sauce.bk       grossMargins
# 212  sauce.bk      ebitdaMargins
# 213  sauce.bk   operatingMargins
# 214  sauce.bk  financialCurrency
# 215  sauce.bk   trailingPegRatio
#
#                                                 Recent
# 0                           130 - 132 Sindhorn Tower 2
# 1    9th floor, Wireless Road Kwang Lumpini Khet Pa...
# 2                                              Bangkok
# 3                                                10330
# 4                                             Thailand
# ..                                                 ...
# 211                                            0.41687
# 212                                            0.29105
# 213                                            0.27046
# ...

# %%
currentprice = combined_data[combined_data["Attribute"]=="currentPrice"].reset_index()
del currentprice["index"] # clean up unnecessary column

currentprice
# Out:
#      Ticker     Attribute Recent
# 0     xo.bk  currentPrice   24.3
# 1  sauce.bk  currentPrice  40.25

# %%
currentprice_sorted = currentprice.sort_values('Recent',ascending=False)
currentprice_sorted
# Out:
#      Ticker     Attribute Recent
# 1  sauce.bk  currentPrice  40.25
# 0     xo.bk  currentPrice   24.3

# %%
data.info['marketCap']
# Out:
# 14490000384
