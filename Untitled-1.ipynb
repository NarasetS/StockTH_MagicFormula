# %%
from yahoo_fin.stock_info import get_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from yahoo_fin.stock_info import get_data
#
# ModuleNotFoundError: No module named 'yahoo_fin'

# %%
price= get_data("sauce.bk", start_date="01/01/2024", end_date="04/30/2024", index_as_date = True, interval="1d")
price['close'].plot()
# Out:
# <Axes: >
