# %%
import yfinance as yf

# %%
GetFacebookInformation = yf.Ticker("sauce.bk")
 
# get all key value pairs that are available
for key, value in GetFacebookInformation.info.items():
    print(key, ":", value)
# Out:
# address1 : 208 Moo 6 Taiban Road
# address2 : Taiban Sub-District Muang District
# city : Samutprakarn
# zip : 10280
# country : Thailand
# phone : 66 2 703 4444
# fax : 66 2 387 1163
# website : https://www.thaitheparos.com
# industry : Packaged Foods
# industryKey : packaged-foods
# industryDisp : Packaged Foods
# sector : Consumer Defensive
# sectorKey : consumer-defensive
# sectorDisp : Consumer Defensive
# ...

# %%
print(GetFacebookInformation.history(period="max"))
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2000-01-04 00:00:00+07:00   0.739390   0.739390   0.728015   0.728015   76000
# 2000-01-05 00:00:00+07:00   0.705264   0.705264   0.699576   0.699576  862000
# 2000-01-06 00:00:00+07:00   0.705264   0.705264   0.693889   0.693889  175000
# 2000-01-07 00:00:00+07:00   0.705264   0.705264   0.705264   0.705264  365000
# 2000-01-10 00:00:00+07:00   0.705264   0.705264   0.705264   0.705264  240000
# ...                              ...        ...        ...        ...     ...
# 2024-08-16 00:00:00+07:00  40.250000  40.750000  40.250000  40.750000    4500
# 2024-08-19 00:00:00+07:00  40.750000  40.750000  40.750000  40.750000       0
# 2024-08-20 00:00:00+07:00  40.750000  41.000000  40.000000  40.500000   27700
# 2024-08-21 00:00:00+07:00  40.750000  40.750000  40.000000  40.500000   13200
# 2024-08-22 00:00:00+07:00  40.250000  40.500000  40.250000  40.250000    6661
#
# ...

# %%
GetFacebookInformation.financials
# Out:
#                                                       2023-12-31  \
# Tax Effect Of Unusual Items                                  0.0
# Tax Rate For Calcs                                         0.201
# Normalized EBITDA                                    980335715.0
# Total Unusual Items                                          NaN
# Total Unusual Items Excluding Goodwill                       NaN
# Net Income From Continuing Operation Net Minori...   739603415.0
# Reconciled Depreciation                              105304452.0
# Reconciled Cost Of Revenue                          2096405548.0
# EBITDA                                               980335715.0
# EBIT                                                 875031263.0
# Net Interest Income                                   10832000.0
# Interest Income                                       10832000.0
# Normalized Income                                    739603415.0
# ...

# %%
GetFacebookInformation.quarterly_financials
# Out:
#                                                      2024-06-30   2024-03-31  \
# Tax Effect Of Unusual Items                                 0.0          0.0
# Tax Rate For Calcs                                     0.198851     0.199911
# Normalized EBITDA                                   236159000.0  256010000.0
# Net Income From Continuing Operation Net Minori...  179801000.0  197878000.0
# Reconciled Depreciation                              25561000.0   24739000.0
# Reconciled Cost Of Revenue                          525924000.0  556070000.0
# EBITDA                                              236159000.0  256010000.0
# EBIT                                                210598000.0  231271000.0
# Normalized Income                                   179801000.0  197878000.0
# Net Income From Continuing And Discontinued Ope...  179801000.0  197878000.0
# Total Expenses                                      645123000.0  663934000.0
# ...
