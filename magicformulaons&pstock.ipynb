# %% [markdown]
# ########## choose stock list (aka market) ##################

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import date

# %%
## To acquire stock list in S&P500 ###
ex1 = pd.read_csv('stock_info_s&p500.csv')
df = pd.DataFrame(ex1['Symbol'].astype('str'))
df = df.rename(columns={'Symbol' : 'ticker'})
df = df.drop_duplicates()
df = df.reset_index(drop=True)
df
df
# Out:
#     ticker
# 0     AAPL
# 1     MSFT
# 2     NVDA
# 3    GOOGL
# 4     GOOG
# ..     ...
# 498   BBWI
# 499    BWA
# 500   NCLH
# 501    AAL
# 502   ETSY
#
# [503 rows x 1 columns]

# %% [markdown]
# ### Acquire informations from yfinance function >> .info

# %%
# 1st pulling date for this data #
df['date_pulling'] = date.today()

# %%
# 2nd acquiring information from .info #
info_attribute_list = [
    'industry',
    'sector',
    'enterpriseValue',
    'totalCashPerShare'
]
# 3rd acquiring information from .quarterly_balance_sheet #
balancesheet_list = [
    'Total Assets',
    'Current Liabilities'
]

# 4th acquiring information from .quarterly_financials #
ttm = 4
financials_list = [
    'EBIT',
    'Operating Income'
]

info_attribute_list_buffer = []
balancesheet_list_buffer = []
financials_list_buffer = []
for i in range(len(df)):
    # print(i, " ",df['ticker'][i])
    yfticker = yf.Ticker(df['ticker'][i])

    # 2nd acquiring information from .info #
    info_attribute_list_buffer_r = []
    for j in range(len(info_attribute_list)):
        try:
            info_attribute_list_buffer_r.append(yfticker.info[info_attribute_list[j]])
        except:
            info_attribute_list_buffer_r.append(None)
    info_attribute_list_buffer.append(info_attribute_list_buffer_r)

    # 3rd acquiring information from .balancesheet #
    balancesheet_list_buffer_r = []
    for j in range(len(balancesheet_list)):
        try:
            balancesheet_list_buffer_r.append(yfticker.quarterly_balance_sheet.loc[yfticker.quarterly_balance_sheet.index == balancesheet_list[j]].values[0][0])
        except:
            balancesheet_list_buffer_r.append(None)
    balancesheet_list_buffer.append(balancesheet_list_buffer_r)

    # 4th acquiring information from .quarterly_financials #
    financials_list_buffer_r = []
    for j in range(len(financials_list)):
        try:
            financials_list_buffer_r.append(np.array([yfticker.quarterly_financials.loc[yfticker.quarterly_financials.index == financials_list[j]].values[0][i] for i in range(ttm)]).sum())
        except:
            financials_list_buffer_r.append(None)
    try:
        financials_list_buffer_r.append(yfticker.quarterly_financials.columns[0])
    except:
        financials_list_buffer_r.append(None)
    financials_list_buffer.append(financials_list_buffer_r)

financials_list.append('ttm_latest')
df = df.join(pd.DataFrame(info_attribute_list_buffer, columns=info_attribute_list))
df = df.join(pd.DataFrame(balancesheet_list_buffer, columns=balancesheet_list))
df = df.join(pd.DataFrame(financials_list_buffer, columns=financials_list))


#### Drop NAN #############
df = df.dropna()
##### Drop where marketcap and EBIT < 0#############
df = df.loc[df['enterpriseValue'] >0]
df = df.loc[df['EBIT'] >0]
df = df.loc[df['Operating Income'] >0]
df = df.reset_index(drop=True)

df.to_csv('data_stock_s&p500.csv',index= False)

# %% [markdown]
# ############################################################################

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import date
df = pd.read_csv('data_stock_s&p500.csv')
print('sector', df['sector'].unique())
print('industry', df['industry'].unique())
# Out:
# sector ['Technology' 'Communication Services' 'Consumer Cyclical' 'Healthcare'
#  'Consumer Defensive' 'Energy' 'Financial Services' 'Basic Materials'
#  'Industrials' 'Utilities' 'Real Estate']
# industry ['Consumer Electronics' 'Software - Infrastructure' 'Semiconductors'
#  'Internet Content & Information' 'Internet Retail'
#  'Drug Manufacturers - General' 'Auto Manufacturers' 'Discount Stores'
#  'Healthcare Plans' 'Oil & Gas Integrated' 'Credit Services'
#  'Household & Personal Products' 'Home Improvement Retail'
#  'Beverages - Non-Alcoholic' 'Entertainment' 'Software - Application'
#  'Diagnostics & Research' 'Telecom Services' 'Specialty Chemicals'
#  'Information Technology Services' 'Restaurants' 'Communication Equipment'
#  'Medical Devices' 'Aerospace & Defense' 'Tobacco'
#  'Semiconductor Equipment & Materials' 'Medical Instruments & Supplies'
#  'Farm & Heavy Construction Machinery' 'Utilities - Regulated Electric'
#  'Financial Data & Stock Exchanges' 'Railroads' 'Biotechnology'
#  'Asset Management' 'Oil & Gas E&P' 'Conglomerates'
#  'Footwear & Accessories' 'Travel Services'
#  'Specialty Industrial Machinery' 'REIT - Industrial' 'Computer Hardware'
#  'Integrated Freight & Logistics' 'Insurance Brokers' 'REIT - Specialty'
#  'Medical Care Facilities' 'Confectioners'
#  'Drug Manufacturers - Specialty & Generic' 'Waste Management'
#  'Electronic Components' 'Specialty Business Services'
#  'Building Products & Equipment' 'Medical Distribution'
#  'REIT - Healthcare Facilities' 'Specialty Retail'
#  'Oil & Gas Equipment & Services' 'Copper' 'Lodging'
#  'Oil & Gas Refining & Marketing' 'Utilities - Renewable' 'REIT - Retail'
#  'Residential Construction' 'Oil & Gas Midstream'
#  'Utilities - Diversified' 'Apparel Retail' 'Rental & Leasing Services'
#  'Industrial Distribution' 'Beverages - Brewers' 'Trucking'
#  'Packaged Foods' 'Electronic Gaming & Multimedia'
#  'Engineering & Construction' 'Health Information Services'
#  'Consulting Services' 'Chemicals' 'Food Distribution'
#  'Agricultural Inputs' 'Steel' 'Real Estate Services' 'REIT - Diversified'
#  'Scientific & Technical Instruments' 'Building Materials'
#  'REIT - Residential' 'Resorts & Casinos' 'Farm Products'
#  'Utilities - Regulated Water' 'Utilities - Independent Power Producers'
#  'Pollution & Treatment Controls' 'Airlines' 'Solar'
#  'REIT - Hotel & Motel' 'Personal Services'
#  'Beverages - Wineries & Distilleries' 'Electrical Equipment & Parts'
#  'REIT - Office' 'Utilities - Regulated Gas' 'Auto Parts'
#  'Packaging & Containers' 'Advertising Agencies' 'Tools & Accessories'
#  'Security & Protection Services' 'Apparel Manufacturing' 'Luxury Goods'
#  'Capital Markets']

# %%
### Next I perform calculations for MF_ROC and MF_EY ###
# represents_earning = 'Operating Income'
represents_earning = 'EBIT'

df['MF_ROC'] = df[represents_earning]/(df['Total Assets'] - df['Current Liabilities'])
df['MF_EY'] = df[represents_earning]/df['enterpriseValue']
df
# Out:
#     ticker date_pulling                        industry  \
# 0     AAPL   2024-08-19            Consumer Electronics
# 1     MSFT   2024-08-19       Software - Infrastructure
# 2     NVDA   2024-08-19                  Semiconductors
# 3    GOOGL   2024-08-19  Internet Content & Information
# 4     GOOG   2024-08-19  Internet Content & Information
# ..     ...          ...                             ...
# 416   BBWI   2024-08-19                Specialty Retail
# 417    BWA   2024-08-19                      Auto Parts
# 418   NCLH   2024-08-19                 Travel Services
# 419    AAL   2024-08-19                        Airlines
# 420   ETSY   2024-08-19                 Internet Retail
#
#                      sector  enterpriseValue  totalCashPerShare  Total Assets  \
# 0                Technology     3.476398e+12              4.065  3.316120e+11
# 1                Technology     3.132824e+12             10.162  5.121630e+11
# 2                Technology     3.044467e+12              1.278  7.707200e+10
# 3    Communication Services     1.934032e+12              8.182  4.147700e+11
# 4    Communication Services     1.955943e+12              8.182  4.147700e+11
# ..                      ...              ...                ...           ...
# 416       Consumer Cyclical     1.212913e+10              3.830  5.221000e+09
# 417       Consumer Cyclical     1.021238e+10              5.655  1.410800e+10
# 418       Consumer Cyclical     2.059400e+10              1.351  2.011383e+10
# 419             Industrials     3.705987e+10             13.685  6.412500e+10
# 420       Consumer Cyclical     7.574979e+09              8.713  2.448088e+09
#
#      Current Liabilities          EBIT  Operating Income  ttm_latest  \
# 0           1.316240e+11  1.216250e+11      1.205940e+11  2024-06-30
# 1           1.252860e+11  1.107220e+11      1.094330e+11  2024-06-30
# 2           1.522300e+10  4.914300e+10      4.774000e+10  2024-04-30
# 3           7.791300e+10  1.018210e+11      9.793700e+10  2024-06-30
# 4           7.791300e+10  1.018210e+11      9.793700e+10  2024-06-30
# ..                   ...           ...               ...         ...
# 416         1.221000e+09  1.365000e+09      1.292000e+09  2024-04-30
# 417         3.712000e+09  1.238000e+09      1.261000e+09  2024-06-30
# 418         6.633916e+09  1.204430e+09      1.207603e+09  2024-06-30
# 419         2.461000e+10  1.996000e+09      2.852000e+09  2024-06-30
# 420         5.644850e+08  3.012030e+08      3.422730e+08  2024-06-30
#
#        MF_ROC     MF_EY
# 0    0.608161  0.034986
# 1    0.286194  0.035343
# 2    0.794564  0.016142
# 3    0.302268  0.052647
# 4    0.302268  0.052057
# ..        ...       ...
# 416  0.341250  0.112539
# 417  0.119084  0.121225
# 418  0.089350  0.058485
# 419  0.050512  0.053859
# 420  0.159908  0.039763
#
# [421 rows x 13 columns]

# %%
### Drop Utilities, Energy, and Financial Services  as suggested from the book ###
sectortoexclude = [
    'Utilities',
    'Energy',
    'Financial Services',
    'Real Estate'
]
for i in sectortoexclude:
    print('exclude sector > ',i)
    try:
         
        df = df.loc[df['sector'] != i]
    except:
        None
        
industrytoexclude =[
    'Engineering & Construction',
    'Building Products & Equipment',
    'Building Materials'
]
for i in industrytoexclude:
    print('exclude industry > ',i)
    try:
         
        df = df.loc[df['industry'] != i]
    except:
        None

df = df.reset_index(drop=True)
# Out:
# exclude sector >  Utilities
# exclude sector >  Energy
# exclude sector >  Financial Services
# exclude sector >  Real Estate
# exclude industry >  Engineering & Construction
# exclude industry >  Building Products & Equipment
# exclude industry >  Building Materials

# %%
#### Select market size by choosing ' market ' ###
market =  50000000### in USD
df_market = df.loc[df['enterpriseValue'] >= market]
df_market = df_market.reset_index(drop=True)

# %%
### Ranking regarding MFs####

df_market['Ranking_MF_ROC'] = df_market['MF_ROC'].rank()
df_market['Ranking_MF_EY'] = df_market['MF_EY'].rank()
df_market['Ranking_MF'] = df_market['Ranking_MF_ROC'] + df_market['Ranking_MF_EY']

df_market.loc[df_market['Ranking_MF'] == df_market['Ranking_MF'].max()]
# Out:
#    ticker date_pulling industry              sector  enterpriseValue  \
# 76     MO   2024-08-19  Tobacco  Consumer Defensive     1.108374e+11
#
#     totalCashPerShare  Total Assets  Current Liabilities          EBIT  \
# 76              1.054  3.438700e+10         7.782000e+09  1.467600e+10
#
#     Operating Income  ttm_latest    MF_ROC    MF_EY  Ranking_MF_ROC  \
# 76      1.140900e+10  2024-06-30  0.551626  0.13241           303.0
#
#     Ranking_MF_EY  Ranking_MF
# 76          303.0       606.0

# %%
numstocks = 50
df_sorted = df_market.sort_values(by=['Ranking_MF'],ascending=False)
df_sorted = df_sorted.reset_index(drop=True)
df_sorted[:numstocks]
# Out:
#    ticker date_pulling                             industry  \
# 0      MO   2024-08-19                              Tobacco
# 1     JBL   2024-08-19                Electronic Components
# 2    BBWI   2024-08-19                     Specialty Retail
# 3    ULTA   2024-08-19                     Specialty Retail
# 4     PHM   2024-08-19             Residential Construction
# 5     NVR   2024-08-19             Residential Construction
# 6    EBAY   2024-08-19                      Internet Retail
# 7     HPQ   2024-08-19                    Computer Hardware
# 8    LULU   2024-08-19                       Apparel Retail
# 9    BKNG   2024-08-19                      Travel Services
# 10   PAYC   2024-08-19               Software - Application
# 11   STLD   2024-08-19                                Steel
# 12   VRSN   2024-08-19            Software - Infrastructure
# 13    LOW   2024-08-19              Home Improvement Retail
# 14    CAT   2024-08-19  Farm & Heavy Construction Machinery
# 15    AOS   2024-08-19       Specialty Industrial Machinery
# 16    MOH   2024-08-19                     Healthcare Plans
# 17     DE   2024-08-19  Farm & Heavy Construction Machinery
# 18    BBY   2024-08-19                     Specialty Retail
# 19   MTCH   2024-08-19       Internet Content & Information
# 20    HCA   2024-08-19              Medical Care Facilities
# 21    AZO   2024-08-19                     Specialty Retail
# 22    SNA   2024-08-19                  Tools & Accessories
# 23    IPG   2024-08-19                 Advertising Agencies
# 24   PCAR   2024-08-19  Farm & Heavy Construction Machinery
# 25    ITW   2024-08-19       Specialty Industrial Machinery
# 26    DHI   2024-08-19             Residential Construction
# 27    NUE   2024-08-19                                Steel
# 28   EXPD   2024-08-19       Integrated Freight & Logistics
# 29     PM   2024-08-19                              Tobacco
# 30    GWW   2024-08-19              Industrial Distribution
# 31   OTIS   2024-08-19       Specialty Industrial Machinery
# 32    DOV   2024-08-19       Specialty Industrial Machinery
# 33   PAYX   2024-08-19               Software - Application
# 34    OMC   2024-08-19                 Advertising Agencies
# 35   CTSH   2024-08-19      Information Technology Services
# 36     LW   2024-08-19                       Packaged Foods
# 37    LMT   2024-08-19                  Aerospace & Defense
# 38     HD   2024-08-19              Home Improvement Retail
# 39    ADP   2024-08-19               Software - Application
# 40  GOOGL   2024-08-19       Internet Content & Information
# 41    KMB   2024-08-19        Household & Personal Products
# 42   GOOG   2024-08-19       Internet Content & Information
# 43     ON   2024-08-19                       Semiconductors
# 44   ROST   2024-08-19                       Apparel Retail
# 45    SYY   2024-08-19                    Food Distribution
# 47  0.053404           258.0          205.0       463.0
# 48  0.064816           220.0          241.0       461.0
# 49  0.078522           190.0          269.0       459.0

# %%
df_sorted.loc[df_sorted['ticker'] == 'NVO']
# Out:
# Empty DataFrame
# Columns: [ticker, date_pulling, industry, sector, enterpriseValue, totalCashPerShare, Total Assets, Current Liabilities, EBIT, Operating Income, ttm_latest, MF_ROC, MF_EY, Ranking_MF_ROC, Ranking_MF_EY, Ranking_MF]
# Index: []

# %%
df_sorted_2 = df_sorted[:numstocks].copy()
df_sorted_2 = df_sorted_2.sort_values(by=['totalCashPerShare'],ascending=False)
df_sorted_2 = df_sorted_2.reset_index(drop=True)
df_sorted_2
# Out:
#    ticker date_pulling                             industry  \
# 0     NVR   2024-08-19             Residential Construction
# 1    BKNG   2024-08-19                      Travel Services
# 2     MOH   2024-08-19                     Healthcare Plans
# 3      RL   2024-08-19                Apparel Manufacturing
# 4      DE   2024-08-19  Farm & Heavy Construction Machinery
# 5     SNA   2024-08-19                  Tools & Accessories
# 6     NUE   2024-08-19                                Steel
# 7     JBL   2024-08-19                Electronic Components
# 8    CPAY   2024-08-19            Software - Infrastructure
# 9     AZO   2024-08-19                     Specialty Retail
# 10    GWW   2024-08-19              Industrial Distribution
# 11   LULU   2024-08-19                       Apparel Retail
# 12   PCAR   2024-08-19  Farm & Heavy Construction Machinery
# 13   ROST   2024-08-19                       Apparel Retail
# 14    OMC   2024-08-19                 Advertising Agencies
# 15   AMAT   2024-08-19  Semiconductor Equipment & Materials
# 16   ULTA   2024-08-19                     Specialty Retail
# 17    LMT   2024-08-19                  Aerospace & Defense
# 18   EBAY   2024-08-19                      Internet Retail
# 19   EXPD   2024-08-19       Integrated Freight & Logistics
# 20    DHI   2024-08-19             Residential Construction
# 21  GOOGL   2024-08-19       Internet Content & Information
# 22   GOOG   2024-08-19       Internet Content & Information
# 23   STLD   2024-08-19                                Steel
# 24    CAT   2024-08-19  Farm & Heavy Construction Machinery
# 25    ADP   2024-08-19               Software - Application
# 26   VRSN   2024-08-19            Software - Infrastructure
# 27    PHM   2024-08-19             Residential Construction
# 28     ON   2024-08-19                       Semiconductors
# 29   PAYC   2024-08-19               Software - Application
# 30    LOW   2024-08-19              Home Improvement Retail
# 31    BBY   2024-08-19                     Specialty Retail
# 32   CTSH   2024-08-19      Information Technology Services
# 33   PAYX   2024-08-19               Software - Application
# 34    IPG   2024-08-19                 Advertising Agencies
# 35   BBWI   2024-08-19                     Specialty Retail
# 36    HCA   2024-08-19              Medical Care Facilities
# 37    KMB   2024-08-19        Household & Personal Products
# 38   MTCH   2024-08-19       Internet Content & Information
# 39     PM   2024-08-19                              Tobacco
# 40    ITW   2024-08-19       Specialty Industrial Machinery
# 41    HPQ   2024-08-19                    Computer Hardware
# 42    DOV   2024-08-19       Specialty Industrial Machinery
# 43   OTIS   2024-08-19       Specialty Industrial Machinery
# 44    HSY   2024-08-19                        Confectioners
# 45     HD   2024-08-19              Home Improvement Retail
# 46    AOS   2024-08-19       Specialty Industrial Machinery
# 47    SYY   2024-08-19                    Food Distribution
# 48     MO   2024-08-19                              Tobacco
# 49     LW   2024-08-19                       Packaged Foods
#
#                     sector  enterpriseValue  totalCashPerShare  Total Assets  \
# 0        Consumer Cyclical     2.528608e+10            792.331  6.407288e+09
# 1        Consumer Cyclical     1.223301e+11            487.019  2.854100e+10
# 2               Healthcare     1.419124e+10            148.481  1.518500e+10
# 3        Consumer Cyclical     1.103516e+10             28.423  6.641000e+09
# 4              Industrials     1.625220e+11             26.080  1.056280e+11
# 5              Industrials     1.462232e+10             23.397  7.759900e+09
# 6          Basic Materials     3.712379e+10             22.896  3.418522e+10
# 7               Technology     1.284190e+10             21.887  1.744900e+10
# 8               Technology     2.633860e+10             20.272  1.619654e+10
# 9        Consumer Cyclical     6.715631e+10             19.669  1.710843e+10
# 10             Industrials     4.944769e+10             15.750  8.352000e+09
# 11       Consumer Cyclical     3.176451e+10             15.205  6.828495e+09
# 12             Industrials     5.654959e+10             14.886  4.117660e+10
# 13       Consumer Cyclical     5.034927e+10             13.953  1.449178e+10
# 14  Communication Services     2.426587e+10             13.860  2.732420e+10
# 15              Technology     1.688794e+11             11.021  3.194900e+10
# 16       Consumer Cyclical     1.936822e+10             10.994  5.631939e+09
# 17             Industrials     1.502455e+11             10.585  5.507600e+10
# 18       Consumer Cyclical     3.015050e+10             10.564  2.037800e+10
# 19             Industrials     1.622700e+10              9.012  4.788341e+09
# 20       Consumer Cyclical     6.161206e+10              8.240  3.515140e+10
# 21  Communication Services     1.934032e+12              8.182  4.147700e+11
# 22  Communication Services     1.955943e+12              8.182  4.147700e+11
# 23         Basic Materials     1.977664e+10              8.090  1.506126e+10
# 24             Industrials     2.003888e+11              7.179  8.333600e+10
# 25              Technology     1.085798e+11              7.144  5.436270e+10
# 26              Technology     1.866734e+10              7.069  1.505100e+09
# 27       Consumer Cyclical     2.632078e+10              6.723  1.654407e+10
# 28              Technology     3.346883e+10              6.259  1.365880e+10
# 29              Technology     8.603141e+09              6.194  4.312744e+09
# 30       Consumer Cyclical     1.744868e+11              5.681  4.536500e+10
# 31       Consumer Cyclical     2.115744e+10              5.628  1.475200e+10
# 32              Technology     3.663261e+10              4.449  1.858000e+10
# 33              Technology     4.447059e+10              4.173  1.038310e+10
# 34  Communication Services     1.461424e+10              4.115  1.701180e+10
# 35       Consumer Cyclical     1.212913e+10              3.830  5.221000e+09
# 36              Healthcare     1.412551e+11              3.557  5.737900e+10
# 37      Consumer Defensive     5.495316e+10              3.453  1.728000e+10
# 38  Communication Services     1.217438e+10              3.271  4.368929e+09
# 39      Consumer Defensive     2.297509e+11              3.092  6.578200e+10
# 40             Industrials     7.944398e+10              2.903  1.557700e+10
# 41              Technology     4.345108e+10              2.572  3.743300e+10
# 42             Industrials     2.756164e+10              2.392  1.129176e+10
# 43             Industrials     4.401971e+10              2.352  9.858000e+09
# 44      Consumer Defensive     4.443558e+10              2.309  1.241567e+10
# 45       Consumer Cyclical     4.214384e+11              1.629  7.923000e+10
# 46             Industrials     1.154838e+10              1.600  3.197600e+09
# 47      Consumer Defensive     4.993393e+10              1.415  2.471234e+10
# 48      Consumer Defensive     1.108374e+11              1.054  3.438700e+10
