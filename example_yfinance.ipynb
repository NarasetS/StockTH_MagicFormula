# %%
import yfinance as yf

# %% [markdown]
# #### Yfinance to acquire fundamental data ######

# %%
stock = 'AVGO'
data = yf.Ticker(stock)
data.info
# Out:
# {'address1': '3421 Hillview Ave',
#  'city': 'Palo Alto',
#  'state': 'CA',
#  'zip': '94304',
#  'country': 'United States',
#  'phone': '650 427 6000',
#  'website': 'https://www.broadcom.com',
#  'industry': 'Semiconductors',
#  'industryKey': 'semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Broadcom Inc. designs, develops, and supplies various semiconductor devices with a focus on complex digital and mixed signal complementary metal oxide semiconductor based devices and analog III-V based products worldwide. The company operates in two segments, Semiconductor Solutions and Infrastructure Software. It provides set-top box system-on-chips (SoCs); cable, digital subscriber line, and passive optical networking central office/consumer premise equipment SoCs; wireless local area network access point SoCs; Ethernet switching and routing custom silicon solutions; serializer/deserializer application specific integrated circuits; optical and copper, and physical layer devices; and fiber optic components and RF semiconductor devices. The company also offers RF front end modules and filter; Wi-Fi, Bluetooth, and global positioning system/global navigation satellite system SoCs; custom touch controllers; inductive charging; attached small computer system interface, and redundant array of independent disks controllers and adapters; peripheral component interconnect express; fiber channel host bus adapters; read channel based SoCs; custom flash controllers; preamplifiers; optocouplers, industrial fiber optics, and motion control encoders and subsystems; light emitting diode, ethernet PHYs, switch ICs, and camera microcontrollers. Its products are used in various applications, including enterprise and data center networking, home connectivity, set-top boxes, broadband access, telecommunication equipment, smartphones and base stations, data center servers and storage systems, factory automation, power generation and alternative energy systems, and electronic displays. Broadcom Inc. was founded in 1961 and is headquartered in Palo Alto, California.',
#  'fullTimeEmployees': 20000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Hock E. Tan',
#    'age': 71,
#    'title': 'President, CEO & Executive Director',
#    'yearBorn': 1952,
#    'fiscalYear': 2023,
#    'totalPay': 1286161,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Kirsten M. Spears',
#    'age': 59,
#    'title': 'CFO & Chief Accounting Officer',
#    'yearBorn': 1964,
#    'fiscalYear': 2023,
#    'totalPay': 932075,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mark D. Brazeal',
#    'age': 55,
#    'title': 'Chief Legal & Corporate Affairs Officer',
#    'yearBorn': 1968,
#    'fiscalYear': 2023,
#    'totalPay': 1184784,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Charlie B. Kawwas Ph.D.',
#    'age': 52,
#    'title': 'President of Semiconductor Solutions',
#    'yearBorn': 1971,
#    'fiscalYear': 2023,
#    'totalPay': 1522515,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Alan  Davidson',
#    'title': 'Chief Information Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ji  Yoo',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Jill  Turner',
#    'title': 'Vice President of Human Resources',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Frank  Ostojic',
#    'title': 'Senior VP & GM of ASIC Products Division',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Rich  Nelson',
#    'title': 'Senior VP & GM of Broadband Video Group',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Ed  Redmond',
#    'title': 'Senior VP & GM of Compute & Connectivity Division',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 5,
#  'boardRisk': 2,
#  'compensationRisk': 10,
#  'shareHolderRightsRisk': 3,
#  'overallRisk': 9,
#  'governanceEpochDate': 1722470400,
#  'compensationAsOfEpochDate': 1703980800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 162.34,
#  'open': 165.025,
#  'dayLow': 163.46,
#  'dayHigh': 168.28,
#  'regularMarketPreviousClose': 162.34,
#  'regularMarketOpen': 165.025,
#  'regularMarketDayLow': 163.46,
#  'regularMarketDayHigh': 168.28,
#  'dividendRate': 2.1,
#  'dividendYield': 0.0126,
#  'exDividendDate': 1719187200,
#  'payoutRatio': 0.84879994,
#  'fiveYearAvgDividendYield': 2.85,
#  'beta': 1.188,
#  'trailingPE': 71.39915,
#  'forwardPE': 27.49752,
#  'volume': 18800739,
#  'regularMarketVolume': 18800739,
#  'averageVolume': 37539127,
#  'averageVolume10days': 21207160,
#  'averageDailyVolume10Day': 21207160,
#  'bid': 166.22,
#  'ask': 166.62,
#  'bidSize': 200,
#  'askSize': 300,
#  'marketCap': 774385827840,
#  'fiftyTwoWeekLow': 79.509,
#  'fiftyTwoWeekHigh': 185.162,
#  'priceToSalesTrailing12Months': 18.169968,
#  'fiftyDayAverage': 161.02818,
#  'twoHundredDayAverage': 131.64757,
#  'trailingAnnualDividendRate': 2.035,
#  'trailingAnnualDividendYield': 0.01253542,
#  'currency': 'USD',
#  'enterpriseValue': 97752956928,
#  'profitMargins': 0.24104,
#  'floatShares': 405237780,
#  'sharesOutstanding': 4654879744,
#  'sharesShort': 50938944,
#  'sharesShortPriorMonth': 53739350,
#  'sharesShortPreviousMonthDate': 1719532800,
#  'dateShortInterest': 1722384000,
#  'sharesPercentSharesOut': 0.0109,
#  'heldPercentInsiders': 0.02026,
#  'heldPercentInstitutions': 0.78612,
#  'shortRatio': 1.5,
#  'shortPercentOfFloat': 0.0126,
#  'impliedSharesOutstanding': 4654879744,
#  'bookValue': 59.221,
#  'priceToBook': 2.8091385,
#  'lastFiscalYearEnd': 1698537600,
#  'nextFiscalYearEnd': 1730160000,
#  'mostRecentQuarter': 1627776000,
#  'earningsQuarterlyGrowth': 1.727,
#  'netIncomeToCommon': 10222000128,
#  'trailingEps': 2.33,
#  'forwardEps': 6.05,
#  'pegRatio': 1.91,
#  'lastSplitFactor': '10:1',
#  'lastSplitDate': 1721001600,
#  'enterpriseToRevenue': 2.294,
#  'enterpriseToEbitda': 4.591,
#  '52WeekChange': 0.9319924,
#  'SandP52WeekChange': 0.2709713,
#  'lastDividendValue': 0.525,
#  'lastDividendDate': 1719187200,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'AVGO',
#  'underlyingSymbol': 'AVGO',
#  'shortName': 'Broadcom Inc.',
#  'longName': 'Broadcom Inc.',
#  'firstTradeDateEpochUtc': 1249565400,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': '605f428a-c23f-303d-9bec-7b1a647c1b84',
#  'messageBoardId': 'finmb_25016048',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 166.36,
#  'targetHighPrice': 240.0,
#  'targetLowPrice': 156.0,
#  'targetMeanPrice': 194.48,
#  'targetMedianPrice': 200.0,
#  'recommendationMean': 1.9,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 31,
#  'totalCash': 11105000448,
#  'totalCashPerShare': 27.019,
#  'ebitda': 21290999808,
#  'totalDebt': 40456998912,
#  'quickRatio': 0.759,
#  'currentRatio': 1.254,
#  'totalRevenue': 42618998784,
#  'debtToEquity': 166.032,
#  'revenuePerShare': 9.786,
#  'returnOnAssets': 0.074260004,
#  'returnOnEquity': 0.22229,
#  'freeCashflow': 20222875648,
#  'operatingCashflow': 18941999104,
#  'earningsGrowth': 1.881,
#  'revenueGrowth': 0.164,
#  'grossMargins': 0.74244004,
#  'ebitdaMargins': 0.49957,
#  'operatingMargins': 0.31765,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 1.2248}

# %%
#### Yfinance to acquire fundamental data and print a particular attribute ######
data.info['marketCap']
data.info['enterpriseValue']
# Out:
# 97752956928

# %%
print(data.quarterly_balance_sheet.loc[data.quarterly_balance_sheet.index == 'Total Assets'])
data.quarterly_balance_sheet.loc[data.quarterly_balance_sheet.index == 'Total Assets'].values[0][0]
# Out:
#                   2024-04-30      2024-01-31     2023-10-31     2023-07-31  \
# Total Assets  175211000000.0  177870000000.0  72861000000.0  71595000000.0
#
#                  2023-04-30
# Total Assets  71667000000.0
# 175211000000.0

# %%
import numpy as np
print(data.quarterly_financials.loc[data.quarterly_financials.index == 'EBIT'].values[0])
test = np.array([data.quarterly_financials.loc[data.quarterly_financials.index == 'EBIT'].values[0][i] for i in range(4)])
print(test.sum())
# Out:
# [3052000000.0 2268000000.0 4372000000.0 3980000000.0 4121000000.0 nan]
# 13672000000.0

# %%
# data_ebit_ttm = data.quarterly_financials['EBIT'].sum(axis=1)
# data_ebit_ttm
test = data.quarterly_financials
list_col = test.columns
test = test.reset_index()
print(list_col)
test['ttm'] = 0
ttm_period = 4
for i in range(4): 
    test['ttm'] = test['ttm'] + test[list_col[i]]

test = test.set_index('index')
test
# Out:
# DatetimeIndex(['2024-04-30', '2024-01-31', '2023-10-31', '2023-07-31',
#                '2023-04-30', '2023-01-31'],
#               dtype='datetime64[ns]', freq=None)
#                                                    2024-04-30 00:00:00  \
# index
# Tax Effect Of Unusual Items                                -61320000.0
# Tax Rate For Calcs                                                0.21
# Normalized EBITDA                                         5874000000.0
# Total Unusual Items                                       -292000000.0
# Total Unusual Items Excluding Goodwill                    -292000000.0
# Net Income From Continuing Operation Net Minori...        2121000000.0
# Reconciled Depreciation                                   2530000000.0
# Reconciled Cost Of Revenue                                3008000000.0
# EBITDA                                                    5582000000.0
# EBIT                                                      3052000000.0
# Net Interest Income                                      -1047000000.0
# Interest Expense                                          1047000000.0
# Normalized Income                                         2351680000.0
# Net Income From Continuing And Discontinued Ope...        2121000000.0
# Total Expenses                                            9230000000.0
# Total Operating Income As Reported                        2965000000.0
# Diluted Average Shares                                    4800000000.0
# Basic Average Shares                                      4650000000.0
# Diluted EPS                                                      0.442
# Basic EPS                                                        0.456
# Diluted NI Availto Com Stockholders                       2121000000.0
# Net Income Common Stockholders                            2121000000.0
# Net Income                                                2121000000.0
# Net Income Including Noncontrolling Interests             2121000000.0
# Net Income Discontinuous Operations                                0.0
# Net Income Continuous Operations                          2121000000.0
# Tax Provision                                             -116000000.0
# Pretax Income                                             2005000000.0
# Other Income Expense                                      -205000000.0
# Other Non Operating Income Expenses                         87000000.0
# Special Income Charges                                    -292000000.0
# Restructuring And Mergern Acquisition                      292000000.0
# Net Non Operating Interest Income Expense                -1047000000.0
# Interest Expense Non Operating                            1047000000.0
# Operating Income                                          3257000000.0
# Operating Expense                                         4519000000.0
# Depreciation Amortization Depletion Income Stat...         827000000.0
# Depreciation And Amortization In Income Statement          827000000.0
# Amortization                                               827000000.0
# Amortization Of Intangibles Income Statement               827000000.0
# Total Unusual Items Excluding Goodwill                      -9000000.0
# Net Income From Continuing Operation Net Minori...        3481000000.0
# Reconciled Depreciation                                    939000000.0
# Reconciled Cost Of Revenue                                2027000000.0
# EBITDA                                                    5060000000.0
# EBIT                                                      4121000000.0
# Net Interest Income                                       -405000000.0
# Interest Expense                                           405000000.0
# Normalized Income                                    3489430839.612487
# Net Income From Continuing And Discontinued Ope...        3481000000.0
# Total Expenses                                            4716000000.0
# Total Operating Income As Reported                        4008000000.0
# Diluted Average Shares                                    4270000000.0
# Basic Average Shares                                      4150000000.0
# Diluted EPS                                                      0.815
# Basic EPS                                                        0.839
# Diluted NI Availto Com Stockholders                       3481000000.0
# Net Income Common Stockholders                            3481000000.0
# Net Income                                                3481000000.0
# Net Income Including Noncontrolling Interests             3481000000.0
# Net Income Discontinuous Operations                                0.0
# Net Income Continuous Operations                          3481000000.0
# Tax Provision                                              235000000.0
# Pretax Income                                             3716000000.0
# Other Income Expense                                       104000000.0
# Other Non Operating Income Expenses                        113000000.0
# Special Income Charges                                      -9000000.0
# Restructuring And Mergern Acquisition                        9000000.0
# Net Non Operating Interest Income Expense                 -405000000.0
# Interest Expense Non Operating                             405000000.0
# Operating Income                                          4017000000.0
# Operating Expense                                         2098000000.0
# Depreciation Amortization Depletion Income Stat...         348000000.0
# Depreciation And Amortization In Income Statement          348000000.0
# Amortization                                               348000000.0
# Amortization Of Intangibles Income Statement               348000000.0
# Research And Development                                  1312000000.0
# Selling General And Administration                         438000000.0
# Gross Profit                                              6115000000.0
# Cost Of Revenue                                           2618000000.0
# Total Revenue                                             8733000000.0
# Operating Revenue                                         8733000000.0
#
#                                                    2023-01-31 00:00:00  \
# index
# Tax Effect Of Unusual Items                                        NaN
# Tax Rate For Calcs                                                 NaN
# Normalized EBITDA                                                  NaN
# Total Unusual Items                                                NaN
# Total Unusual Items Excluding Goodwill                             NaN
# Net Income From Continuing Operation Net Minori...                 NaN
# Reconciled Depreciation                                            NaN
# Reconciled Cost Of Revenue                                         NaN
# EBITDA                                                             NaN
# EBIT                                                               NaN
# Net Interest Income                                                NaN
# Interest Expense                                                   NaN
# Normalized Income                                                  NaN
# Net Income From Continuing And Discontinued Ope...                 NaN
# Total Expenses                                                     NaN
# Total Operating Income As Reported                                 NaN
# Diluted Average Shares                                             NaN
# Basic Average Shares                                               NaN
# Diluted EPS                                                        NaN
# Basic EPS                                                          NaN
# Diluted NI Availto Com Stockholders                                NaN
# Net Income Common Stockholders                                     NaN
# Net Income                                                         NaN
# Net Income Including Noncontrolling Interests                      NaN
# Net Income Discontinuous Operations                                0.0
# Net Income Continuous Operations                                   NaN
# Tax Provision                                                      NaN
# Pretax Income                                                      NaN
# Other Income Expense                                               NaN
# Other Non Operating Income Expenses                                NaN
# Special Income Charges                                             NaN
# Restructuring And Mergern Acquisition                              NaN
# Net Non Operating Interest Income Expense                          NaN
# Interest Expense Non Operating                                     NaN
# Operating Income                                                   NaN
# Operating Expense                                                  NaN
# Depreciation Amortization Depletion Income Stat...                 NaN
# Depreciation And Amortization In Income Statement                  NaN
# Amortization                                                       NaN
# Amortization Of Intangibles Income Statement                       NaN
# Research And Development                                           NaN
# Selling General And Administration                                 NaN
# Gross Profit                                                       NaN
# Cost Of Revenue                                                    NaN
# Total Revenue                                                      NaN
# Operating Revenue                                                  NaN
#
#                                                                    ttm
# index
# Tax Effect Of Unusual Items                          -109034125.903764
# Tax Rate For Calcs                                            0.448167
# Normalized EBITDA                                        21537000000.0
# Total Unusual Items                                      -1126000000.0
# Total Unusual Items Excluding Goodwill                   -1126000000.0
# Net Income From Continuing Operation Net Minori...       10222000000.0
# Reconciled Depreciation                                   6739000000.0
# Reconciled Cost Of Revenue                               10475000000.0
# EBITDA                                                   20411000000.0
# EBIT                                                     13672000000.0
# Net Interest Income                                      -2249000000.0
# Interest Expense                                          2784000000.0
# Normalized Income                                   11238965874.096235
# Net Income From Continuing And Discontinued Ope...       10273000000.0
# Total Expenses                                           28338000000.0
# Total Operating Income As Reported                       13144000000.0
# Diluted Average Shares                                   18010000000.0
# Basic Average Shares                                     17430000000.0
# Diluted EPS                                                      2.325
# Basic EPS                                                        2.402
# Diluted NI Availto Com Stockholders                      10273000000.0
# Net Income Common Stockholders                           10273000000.0
# Net Income                                               10273000000.0
# Net Income Including Noncontrolling Interests            10273000000.0
# Net Income Discontinuous Operations                                NaN
# Net Income Continuous Operations                         10222000000.0
# Tax Provision                                              666000000.0
# Pretax Income                                            10888000000.0
# Other Income Expense                                     -1144000000.0
# Other Non Operating Income Expenses                        -18000000.0
# Special Income Charges                                   -1137000000.0
# Restructuring And Mergern Acquisition                     1137000000.0
# Net Non Operating Interest Income Expense                -2249000000.0
# Interest Expense Non Operating                            2784000000.0
# Operating Income                                         14281000000.0
# Operating Expense                                        13441000000.0
# Depreciation Amortization Depletion Income Stat...        2317000000.0
# Depreciation And Amortization In Income Statement         2317000000.0
# Amortization                                              2317000000.0
# Amortization Of Intangibles Income Statement              2317000000.0
# Research And Development                                  7469000000.0
# Selling General And Administration                        3655000000.0
# Gross Profit                                             27722000000.0
# Cost Of Revenue                                          14897000000.0
# Total Revenue                                            42619000000.0
# Operating Revenue                                        42619000000.0

# %%
test.loc[test.index == 'EBIT']
# Out:
#       2024-04-30 00:00:00 2024-01-31 00:00:00 2023-10-31 00:00:00  \
# index
# EBIT         3052000000.0        2268000000.0        4372000000.0
#
#       2023-07-31 00:00:00 2023-04-30 00:00:00 2023-01-31 00:00:00  \
# index
# EBIT         3980000000.0        4121000000.0                 NaN
#
#                  ttm
# index
# EBIT   13672000000.0

# %%
test.loc[test.index == 'Operating Income']
# Out:
#                  2024-04-30 00:00:00 2024-01-31 00:00:00 2023-10-31 00:00:00  \
# index
# Operating Income        3257000000.0        2703000000.0        4253000000.0
#
#                  2023-07-31 00:00:00 2023-04-30 00:00:00 2023-01-31 00:00:00  \
# index
# Operating Income        4068000000.0        4017000000.0                 NaN
#
#                             ttm
# index
# Operating Income  14281000000.0
